# %%
import pandas as pd
import ast
import pyGM as gm
import numpy as np
import math

# %%
#upload card db
cards = pd.read_csv('data/cards.csv')

# %%
# add converted mana cost as well as make all values not strings
cards['CMC'] = cards['manaCost'].apply(lambda x: ''.join(''.join(str(x).split('{')).split('}')))
for col in cards:
    try:
        cards[col] = cards[col].apply(lambda x: ast.literal_eval(x))
    except:
        pass
for index, row in cards.iterrows():
    X = row['CMC']
    list(X)
    x_ = 0
    for x in X:
        try:
            x_+=int(x)
        except:
            x_+=1
    row['CMC']=x_

# %%
# only keep modern legal cards and drop non useful cols
legal = []
for index, row in cards.iterrows():
    if 'modern' in row['legalities']:
        if row['legalities']['modern']=='Legal':
            legal.append(True)
        else:
            legal.append(False)
    else:
        legal.append(False)
cards = cards[legal]
cards.drop(columns=['legalities','Unnamed: 0','leadershipSkills','power','toughness','loyalty','uuid'],inplace=True)

# %%
cards
# Out:
#           colors       manaCost                          name  \
# 8            [R]         {2}{R}                Abandon Reason
# 10            []            {3}         Abandoned Sarcophagus
# 11           [B]         {3}{B}                Abattoir Ghoul
# 13           [W]         {3}{W}                 Abbey Griffin
# 15           [R]         {1}{R}           Abbot of Keral Keep
# 17           [U]         {3}{U}           Aberrant Researcher
# 19           [B]      {5}{B}{B}            Abhorrent Overlord
# 22           [B]         {1}{B}            Abnormal Endurance
# 24            []            NaN       Abolisher of Bloodlines
# 25        [G, U]      {2}{G}{U}           Abominable Treefolk
# 27     [B, G, U]   {3}{B}{G}{U}          Abomination of Gudul
# 32           [R]         {1}{R}                        Abrade
# 33        [B, G]         {B}{G}                  Abrupt Decay
# 36           [W]         {3}{W}               Absolver Thrull
# 37        [U, W]      {W}{U}{U}                        Absorb
# 38           [B]         {6}{B}                    Absorb Vis
# 40            []         {2}{U}         Abstruse Interference
# 42           [W]         {1}{W}                 Abuna Acolyte
# 43           [W]         {3}{W}                 Abuna's Chant
# 44           [G]      {2}{G}{G}                     Abundance
# 45           [G]            {G}               Abundant Growth
# 46            []            {8}                  Abundant Maw
# 51           [B]      {1}{B}{B}             Abyssal Nocturnus
# 52           [B]      {2}{B}{B}            Abyssal Persecutor
# 53           [B]      {2}{B}{B}               Abyssal Specter
# 54           [W]         {1}{W}               Abzan Advantage
# 55     [B, G, W]      {W}{B}{G}              Abzan Ascendancy
# 56            []            {3}                  Abzan Banner
# 57           [W]         {3}{W}           Abzan Battle Priest
# 58           [G]         {2}{G}             Abzan Beastmaster
# ...          ...            ...                           ...
# 20971        [U]         {2}{U}                 Zephyr Scribe
# 20972        [U]         {5}{U}                 Zephyr Spirit
# 20973        [U]            {U}                 Zephyr Sprite
# 20975        [W]      {6}{W}{W}          Zetalpa, Primal Dawn
# 20976        [W]         {2}{W}           Zhalfirin Commander
# 20978        [W]         {1}{W}               Zhalfirin Decoy
# 20980         []            NaN                Zhalfirin Void
# 20987     [G, R]      {3}{R}{G}              Zhur-Taa Ancient
# 20988     [G, R]         {R}{G}                Zhur-Taa Druid
# 20989     [G, R]         {R}{G}               Zhur-Taa Goblin
# 20990     [G, R]      {3}{R}{G}                Zhur-Taa Swine
# 20991     [G, R]      {3}{R}{G}  Zilortha, Strength Incarnate
# 20992     [R, W]  {1}{R/W}{R/W}          Zirda, the Dawnwaker
# 20996        [R]      {1}{R}{R}            Zo-Zu the Punisher
# 21001        [G]         {1}{G}                 Zodiac Monkey
# 21009         []            NaN                 Zoetic Cavern
# 21010        [B]         {3}{B}                     Zof Shade
# 21011        [B]   {3}{B}{B}{B}             Zombie Apocalypse
# 21018        [B]         {4}{B}                Zombie Goliath
# 21019        [B]         {1}{B}            Zombie Infestation
# 21022        [B]         {3}{B}                 Zombie Musher
# 21023     [B, U]         {U}{B}              Zombie Outlander
# 21027        [B]         {3}{B}                       Zombify
# 21030        [B]         {3}{B}            Zulaport Chainmage
# 21031        [B]         {1}{B}            Zulaport Cutthroat
# 21032        [B]            {B}             Zulaport Enforcer
# 21034  [B, U, W]   {1}{W}{U}{B}             Zur the Enchanter
# 21035        [U]         {3}{U}                Zur's Weirding
# 21039        [R]            {R}             Zurgo Bellstriker
# 21040  [B, R, W]   {2}{R}{W}{B}             Zurgo Helmsmasher
#
#                     subtypes   supertypes  \
# 8                         []           []
# 10                        []           []
# 11                  [Zombie]           []
# 13                 [Griffin]           []
# 15             [Human, Monk]           []
# 17           [Human, Insect]           []
# 19                   [Demon]           []
# 22                        []           []
# 24        [Eldrazi, Vampire]           []
# 25                [Treefolk]       [Snow]
# 27                  [Horror]           []
# 32                        []           []
# 33                        []           []
# 36          [Thrull, Cleric]           []
# 37                        []           []
# 38                        []           []
# 40                        []           []
# 42             [Cat, Cleric]           []
# 43                        []           []
# 44                        []           []
# 45                    [Aura]           []
# 46          [Eldrazi, Leech]           []
# 51                  [Horror]           []
# 52                   [Demon]           []
# 53                 [Specter]           []
# 54                        []           []
# 55                        []           []
# 56                        []           []
# 57           [Human, Cleric]           []
# 58           [Hound, Shaman]           []
# ...                      ...          ...
# 20971          [Human, Monk]           []
# 20972               [Spirit]           []
# 20973               [Faerie]           []
# 20975      [Elder, Dinosaur]  [Legendary]
# 20976        [Human, Knight]           []
# 20978       [Human, Soldier]           []
# 20980                     []           []
# 20987                [Beast]           []
# 20988         [Human, Druid]           []
# 20989    [Goblin, Berserker]           []
# 20990                 [Boar]           []
# 20991             [Dinosaur]  [Legendary]
# 20992       [Elemental, Fox]  [Legendary]
# 20996      [Goblin, Warrior]  [Legendary]
# 21001               [Monkey]           []
# 21009                     []           []
# 21010                [Shade]           []
# 21011                     []           []
# 21018        [Zombie, Giant]           []
# 21019                     []           []
# 21022               [Zombie]       [Snow]
# 21023        [Zombie, Scout]           []
# 21027                     []           []
# 21030  [Human, Shaman, Ally]           []
# 21031   [Human, Rogue, Ally]           []
# 21032       [Human, Warrior]           []
# 21034        [Human, Wizard]  [Legendary]
# 21035                     []           []
# 21039         [Orc, Warrior]  [Legendary]
# 21040         [Orc, Warrior]  [Legendary]
#
#                                                     text  \
# 8                      [discard, discard, cast, madness]
# 10                       [cast, cycling, cycling, exile]
# 11                                            [creature]
# 13                                           [vigilance]
# 15                         [cast, creature, exile, play]
# 17                         [instant, sorcery, transform]
# 19          [create, Harpy, creature, flying, sacrifice]
# 22                                  [creature, creature]
# 24                                            [creature]
# 25                        [Treefolk, creature, creature]
# 27                      [discard, cast, creature, morph]
# 32                                                    []
# 33                                                    []
# 36          [creature, exile, Thrull, creature, destroy]
# 37                                                    []
# 38                               [land, reveal, shuffle]
# 40                    [create, Eldrazi, Scion, creature]
# 42                                  [artifact, creature]
# 43                                   [creature, entwine]
# 44                                [land, reveal, reveal]
# 45                                          [land, land]
# 46                        [cast, creature, emerge, cast]
# 51                                      [fear, artifact]
# 52                                             [trample]
# 53                                             [Specter]
# 54                                   [creature, counter]
# 55     [counter, creature, creature, create, Spirit, ...
# 56                                                    []
# 57                          [counter, creature, counter]
# 58                                            [creature]
# ...                                                  ...
# 20971                                    [discard, cast]
# 20972                                           [Spirit]
# 20973                                                 []
# 20975                           [double, indestructible]
# 20976   [creature, flanking, creature, Knight, creature]
# 20978                                         [creature]
# 20980                                             [scry]
# 20987                                       [land, land]
# 20988                                            [Druid]
# 20989                                [creature, counter]
# 20990                                         [creature]
# 20991                                                 []
# 20992                         [cast, activate, creature]
# 20996                                             [land]
# 21001                                         [creature]
# 21009                            [cast, creature, morph]
# 21010                                            [Shade]
# 21011                        [Zombie, creature, destroy]
# 21018                                                 []
# 21019                                 [Zombie, creature]
# 21022                       [landwalk, creature, Zombie]
# 21023                                                 []
# 21027                                         [creature]
# 21030                                             [Ally]
# 21031                                         [creature]
# 21032                                          [counter]
# 21034                     [search, enchantment, shuffle]
# 21035                                     [play, reveal]
# 21039                                       [cast, dash]
# 21040                [indestructible, creature, counter]
#
#                                       type          types hasNoDeckLimit CMC
# 8                                  Instant      [Instant]            NaN   3
# 10                                Artifact     [Artifact]            NaN   3
# 11                       Creature — Zombie     [Creature]            NaN   4
# 13                      Creature — Griffin     [Creature]            NaN   4
# 15                   Creature — Human Monk     [Creature]            NaN   2
# 17                 Creature — Human Insect     [Creature]            NaN   4
# 19                        Creature — Demon     [Creature]            NaN   7
# 22                                 Instant      [Instant]            NaN   2
# 24              Creature — Eldrazi Vampire     [Creature]            NaN   3
# 25                Snow Creature — Treefolk     [Creature]            NaN   4
# 27                       Creature — Horror     [Creature]            NaN   6
# 32                                 Instant      [Instant]            NaN   2
# 33                                 Instant      [Instant]            NaN   2
# 36                Creature — Thrull Cleric     [Creature]            NaN   4
# 37                                 Instant      [Instant]            NaN   3
# 38                                 Sorcery      [Sorcery]            NaN   7
# 40                                 Instant      [Instant]            NaN   3
# 42                   Creature — Cat Cleric     [Creature]            NaN   2
# 43                                 Instant      [Instant]            NaN   4
# 44                             Enchantment  [Enchantment]            NaN   4
# 45                      Enchantment — Aura  [Enchantment]            NaN   1
# 46                Creature — Eldrazi Leech     [Creature]            NaN   8
# 51                       Creature — Horror     [Creature]            NaN   3
# 52                        Creature — Demon     [Creature]            NaN   4
# 53                      Creature — Specter     [Creature]            NaN   4
# 54                                 Instant      [Instant]            NaN   2
# 55                             Enchantment  [Enchantment]            NaN   3
# 56                                Artifact     [Artifact]            NaN   3
# 57                 Creature — Human Cleric     [Creature]            NaN   4
# 58                 Creature — Hound Shaman     [Creature]            NaN   3
# ...                                    ...            ...            ...  ..
# 20971                Creature — Human Monk     [Creature]            NaN   3
# 20972                    Creature — Spirit     [Creature]            NaN   6
# 20973                    Creature — Faerie     [Creature]            NaN   1
# 20975  Legendary Creature — Elder Dinosaur     [Creature]            NaN   8
# 20976              Creature — Human Knight     [Creature]            NaN   3
# 20978             Creature — Human Soldier     [Creature]            NaN   2
# 20980                                 Land         [Land]            NaN   3
# 20987                     Creature — Beast     [Creature]            NaN   5
# 20988               Creature — Human Druid     [Creature]            NaN   2
# 20989          Creature — Goblin Berserker     [Creature]            NaN   2
# 20990                      Creature — Boar     [Creature]            NaN   5
# 20991        Legendary Creature — Dinosaur     [Creature]            NaN   5
# 20992   Legendary Creature — Elemental Fox     [Creature]            NaN   7
# 20996  Legendary Creature — Goblin Warrior     [Creature]            NaN   3
# 21001                    Creature — Monkey     [Creature]            NaN   2
# 21009                                 Land         [Land]            NaN   3
# 21010                     Creature — Shade     [Creature]            NaN   4
# 21011                              Sorcery      [Sorcery]            NaN   6
# 21018              Creature — Zombie Giant     [Creature]            NaN   5
# 21019                          Enchantment  [Enchantment]            NaN   2
# 21022               Snow Creature — Zombie     [Creature]            NaN   4
# 21023              Creature — Zombie Scout     [Creature]            NaN   2
# 21027                              Sorcery      [Sorcery]            NaN   4
# 21030         Creature — Human Shaman Ally     [Creature]            NaN   4
# 21031          Creature — Human Rogue Ally     [Creature]            NaN   2
# 21032             Creature — Human Warrior     [Creature]            NaN   1
# 21034    Legendary Creature — Human Wizard     [Creature]            NaN   4
# 21035                          Enchantment  [Enchantment]            NaN   4
# 21039     Legendary Creature — Orc Warrior     [Creature]            NaN   1
# 21040     Legendary Creature — Orc Warrior     [Creature]            NaN   5
#
# [13890 rows x 10 columns]

# %%
#upload decklists
decks = dict()
decks['modern2018'] = pd.read_csv('data/deckListmodernMetaDecks2018.csv')
decks['modern2019'] = pd.read_csv('data/deckListmodernMetaDecks2019.csv')
decks['modern2020'] = pd.read_csv('data/deckListmodernMetaDecks2020.csv')

# %%
#select only one archetype from decklists
decklists = dict()
decklists['modern2020'] = decks['modern2020'][decks['modern2020']['1']=='Bant Control']['3']
decklists['modern2019'] = decks['modern2019'][decks['modern2019']['1']=='Bant Control']['3']
decklists['modern2018'] = decks['modern2018'][decks['modern2018']['1']=='Bant Control']['3']
for d in decklists:
    print(decklists[d],d)
    
decklists['modern2020'] = decklists['modern2020'].to_dict()[28]
decklists['modern2020'] = ast.literal_eval(decklists['modern2020'])
decklists['modern2019'] = decklists['modern2019'].to_dict()[47]
decklists['modern2019'] = ast.literal_eval(decklists['modern2019'])
# Out:
# 28    [{'LANDS': ['2 Breeding Pool', '3 Field of Rui...
# Name: 3, dtype: object modern2020
# 47    [{'LANDS': ['1 Breeding Pool', '2 Celestial Co...
# Name: 3, dtype: object modern2019
# Series([], Name: 3, dtype: object) modern2018

# %%
x = len(decklists['modern2018'])
y = len(decklists['modern2019'])
z = len(decklists['modern2020'])

# %%
#Generate dataframes with card frequencies for all years for main and side
# as well as correlation matrixes for cards
simMain = dict()
simSide = dict()
for D in decklists:
    for i,deck in enumerate(decklists[D]):
        for ty in deck:
            if ty=='SIDEBOARD':
                sim=simSide
            else:
                sim=simMain
            for card in deck[ty]:
                card = card.split(' ')
                freq = card[0]
                name = ' '.join(card[1:])
                if name not in sim:
                    sim[name] = list()
                    if D=='modern2020':
                        i_ = i+x+y
                    if D=='modern2019':
                        i_ = i+x
                    if D=='modern2018':
                        i_ = i
                    sim[name].append([i_,int(freq)])
                else:
                    isIn = False
                    for i_,freq_ in sim[name]:
                        if i_==i:
                            isIn=True
                            freq_+=int(freq)
                    if isIn==False:
                        sim[name].append([i,int(freq)])
                        
                        
sim=simSide
columns=list(sim.keys())
d = pd.DataFrame(columns=columns)
for i in range(x+y+z):
    d.loc[i] = 0.0
for card in sim:
    for deck,freq in sim[card]:
        d.loc[deck][card]=freq
        
corr = d.corr()
for index, row in corr.iterrows():
    for i,r in enumerate(row):
        try:
            int(r)
        except:
            row[i]=-1
corrSide=corr
dSide = d

sim=simMain
columns=list(sim.keys())
d = pd.DataFrame(columns=columns)
for i in range(x+y+z):
    d.loc[i] = 0.0
for card in sim:
    for deck,freq in sim[card]:
        d.loc[deck][card]=freq
        
corr = d.corr()
for index, row in corr.iterrows():
    for i,r in enumerate(row):
        try:
            int(r)
        except:
            row[i]=-1

corrMain = corr
dMain = d

# %%
#select multiple potential cards and impute those values
#https://towardsdatascience.com/preprocessing-regression-imputation-of-missing-continuous-values-f612179bafb4
import pandas as pd
import numpy as np
# explicitly require this experimental feature
from sklearn.experimental import enable_iterative_imputer
# now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import BayesianRidge
import random

x_ = len(dMain)
dMain.loc[x_] = None
for i in range(len(dMain.columns)):
    dMain.loc[x_][i] = np.nan

# %%
#test seed value
seed = dict()
seed['Breeding Pool'] = 4
seed['Misty Rainforest'] = 4
seed['Temple Garden'] = 4

# %%
# used to select card fewqeuencies for non lands
def F(x):
    if x < 0:
        return 0
    if x > 3:
        return 4
    else:
        return math.ceil(x)
# generate a 60 card decklist given a seed list of cards/freqs
def genDeck(seed):
    decksize = 0
    imputer = IterativeImputer(BayesianRidge())
    #impute current seed
    for s in seed:
        decksize+=seed[s]
    while decksize!=60:
        for card in dMain:
            if card in seed:
                dMain.loc[x_][card] = seed[card]
            else:
                dMain.loc[x_][card] = np.nan
        #impute deck givne current seed        
        impMain = pd.DataFrame(imputer.fit_transform(dMain.values),columns = dMain.columns)
        for card in impMain:
            if card in ['Forest', 'Mountain', 'Island', 'Plains', 'Swamp', 'Wastes']:
                impMain[card] = impMain[card].apply(lambda x: math.ceil(x))
            else:
                impMain[card] = impMain[card].apply(F)
        #sort cards not in seed by their average correlatoin w the cards in the seed
        corrs = corrMain[list(seed.keys())].transpose().mean().sort_values(ascending=False).to_dict()
        to_inc = []
        i = 10
        #include top 10 or so cards into the seed (by frequency) at a time then reimpute till 60 cards in deck
        for c in corrs:
            newFreq = impMain.loc[x_][c]
            if c not in seed and newFreq >0:
                if decksize+newFreq<=60:
                    seed[c] = newFreq
                    decksize+=newFreq
                    i-=newFreq
                if i<=0:
                    break

# %%
genDeck(seed)
# Out:
# C:\Users\conal\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:599: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\Users\conal\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:599: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\Users\conal\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:599: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\Users\conal\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:599: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\Users\conal\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:599: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)

# %%
seed
# Out:
# {'Breeding Pool': 4,
#  'Misty Rainforest': 4,
#  'Temple Garden': 4,
#  'Path to Exile': 4,
#  'Ice-Fang Coatl': 4,
#  'Force of Negation': 4,
#  "Arcum's Astrolabe": 4,
#  'Teferi, Time Raveler': 3,
#  'Snow-Covered Island': 4,
#  'Jace, the Mind Sculptor': 2,
#  'Field of Ruin': 2,
#  'Hallowed Fountain': 2,
#  'Snow-Covered Plains': 1,
#  'Flooded Strand': 3,
#  'Mana Leak': 3,
#  'Cryptic Command': 1,
#  'Snow-Covered Forest': 2,
#  'Mystic Sanctuary': 3,
#  'Supreme Verdict': 2,
#  'Snapcaster Mage': 1,
#  "Uro, Titan of Nature's Wrath": 3}

# %%
Decksize = 60
#For a given partial decklist, check if the addition of a new card
# satisfies the restrictions placed upon the deck by specifying a companion(s) for it
# and return True if the addition of a new card would not violate the deck restrictions
def meetsCRestrictions(Companions: list, Card: pd.Series(), Decklist: list) -> bool:
    for i in Companions:
        if i == "Lurrus of the Dream-Den" and ('Creature' in Card.types.tolist()[0] or 'Enchantment' in Card.types.tolist()[0] or 'Artifact' in Card.types.tolist()[0] or 'Planeswalker' in Card.types.tolist()[0]) and Card.CMC.tolist()[0] > 2:
            return False
        if i == "Keruga, the Macrosage" and 'Land' not in Card.types.tolist()[0] and Card.CMC.tolist()[0] < 3:
            return False
        if i == "Jegantha, the Wellspring" and Card.manaCost.tolist()[0].split('}') != len(set(Card.manaCost.tolist()[0].split('}'))):
            return False
        if i == "Obosh, the Preypiercer" and 'Land' not in Card.types.tolist()[0]  and Card.CMC.tolist()[0] %2 == 0:
            return False
        if i == "Gyruda, Doom of Depths" and 'Land' not in Card.types.tolist()[0]  and Card.CMC.tolist()[0] % 2 == 1:
            return False
        if i == "Umori, the Collector":
            CardType = None
            for ty in Decklist:
                for x in Decklist[ty]:
                    name = ' '.join(x.split()[1:])
                    x = cards[cards['name']==name]
                    if CardType == None:
                        CardType = x.types.tolist()[0]
                    elif 'Land' in CardType:
                        CardType = x.types.tolist()[0]
                    elif len(x.types.tolist()[0])>1 and 'Land' not in x.types.tolist()[0]:
                        return False
                    else:
                        if x.types.tolist()[0] != ["Land"] and x.types.tolist()[0] not in CardType:
                            return False
        if i == "Lutri, the Spellchaser":
            for ty in Decklist:
                for x in Decklist[ty]:
                    freq = int(x.split()[0])
                    name  = ' '.join(x.split()[1:])
                    if (freq >1 and ty!='LANDS') or name==Card.name.tolist()[0]:
                        return False

        if i == "Kaheera, the Orphaguard" and 'Creature' in Card.types.tolist()[0]  and ("Cat" not in Card.subtypes.tolist()[0]  or "Elemental" not in Card.subtypes.tolist()[0] or "Nightmare" not in Card.subtypes.tolist()[0] or "Dinosaur" not in Card.subtypes.tolist()[0] or "Beast" not in Card.subtypes.tolist()[0]):
            return False
        if i == "Yorion, Sky Nomad":
            Decksize = 80
    return True

# %%
#Sample decklist to check companion restrictions and recommended cards
sampleDecklist = {}
sampleDecklist["LANDS"] = []
sampleDecklist["CREATURES"] = ["4 Monastery Swiftspear", "2 Magus of the Moon", "4 Goblin Guide"]
sampleDecklist["INSTANTS and SORC."] = ["4 Lightning Bolt", "4 Boros Charm"]
sampleDecklist["SIDEBOARD"] = ["1 Lurrus of the Dream-Den"]
name = 'Lava Axe'
comp = "Kaheera, the Orphaguard"
meetsCRestrictions([comp],cards[cards['name']==name],Decklist=sampleDecklist)
# Out:
# True

# %%
import copy
Companion = []
CompanionList = ["Lurrus of the Dream-Den","Keruga, the Macrosage", "Jegantha, the Wellspring", "Obosh, the Preypiercer", "Gyruda, Doom of Depths", 
                 "Umori, the Collector", "Lutri, the Spellchaser", "Kaheera, the Orphaguard", "Yorion, Sky Nomad"]
def GetRecommended(Data: pd.DataFrame(), IncDeck: dict) -> dict:
    recommendationDeck = pd.Series()
    mainDeck = copy.deepcopy(IncDeck)
    CurrSize = 0
    if 'SIDEBOARD' in IncDeck.keys():
        del mainDeck['SIDEBOARD']
        sideDeck = IncDeck['SIDEBOARD']
        for x in sideDeck:
            x = ' '.join(x.split()[1:])
            potentialCard = cards[cards['name']==x]
            if potentialCard.name.tolist()[0] in CompanionList:
                Companion.append(potentialCard.name.tolist()[0])
    for i in mainDeck.values():
        for x in i:
            print(x)
            nameVal = x.split(" ")
            CurrSize += int(nameVal[0])
    print("Current Deck Size: " + str(CurrSize))
    if len(Companion) != 0:
        print("Companion: " + str(Companion))
    while CurrSize < Decksize:
        CurrSize +=1

# %%
GetRecommended(corrMain, sampleDecklist)
# Out:
# 4 Monastery Swiftspear
# 2 Magus of the Moon
# 4 Goblin Guide
# 4 Lightning Bolt
# 4 Boros Charm
# Current Deck Size: 18
# Companion: ['Lurrus of the Dream-Den']

# %%
def RunTests(Decklist):
    newlist = Decklist["INSTANTS and SORC."]+ Decklist["CREATURES"] + Decklist["LANDS"] + Decklist["OTHER SPELLS"]
    hold = []
    for i in range(len(newlist)):
        hold.append( newlist[i].split(" ") )
        hold[i] = " ".join(hold[i][1:])
    CheckDeck = dict()
    for i in newlist:
        CheckDeck[i[1]] = i[0]
    Testing = newlist[0:int(len(newlist)/3)]
    newSeed = dict()
    for i in Testing:
        newSeed[i[1]] = i[0]
    FinalList = genDeck(seed = newSeed)
    FinalList = FinalList["INSTANTS and SORC."]+ FinalList["CREATURES"] + FinalList["LANDS"] + FinalList["OTHER SPELLS"]
    for i in FinalList:
        i = i.split(" ")
        i = " ".join(i[1:])
    count = 0
    for i in FinalList:
        if i in CheckDeck.keys():
            count += CheckDeck[i]
    return count/len(newlist)

# %%
print("Similarity: " + str(RunTests(decklists['modern2020'][0])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-9b696438006c> in <module>
# ----> 1 print("Similarity: " + str(RunTests(decklists['modern2020'][0])))
#
# <ipython-input-36-fbf7e01232f3> in RunTests(Decklist)
#      12     for i in Testing:
#      13         newSeed[i[1]] = i[0]
# ---> 14     FinalList = genDeck(seed = newSeed)
#      15     FinalList = FinalList["INSTANTS and SORC."]+ FinalList["CREATURES"] + FinalList["LANDS"] + FinalList["OTHER SPELLS"]
#      16     for i in FinalList:
#
# <ipython-input-12-a29b1ceedb13> in genDeck(seed)
#      13     #impute current seed
#      14     for s in seed:
# ---> 15         decksize+=seed[s]
#      16     while decksize!=60:
#      17         for card in dMain:
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'
