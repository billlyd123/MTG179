# %%
import pandas as pd
import ast
import pyGM as

# %%
# !dir data
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 381D-B2B7
#
#  Directory of C:\Users\joey\Downloads\MTG179-master\MTG179-master\data
#
# 06/07/2020  01:46 PM    <DIR>          .
# 06/07/2020  01:46 PM    <DIR>          ..
# 06/07/2020  01:46 PM         5,970,160 cards.csv
# 06/07/2020  01:46 PM         1,811,572 deckListcommandermetadecks2018.csv
# 06/07/2020  01:46 PM         2,961,171 deckListcommandermetadecks2019.csv
# 06/07/2020  01:46 PM           998,613 deckListcommandermetadecks2020.csv
# 06/07/2020  01:46 PM         4,662,228 deckListmodernMetaDecks2018.csv
# 06/07/2020  01:46 PM         4,729,765 deckListmodernMetaDecks2019.csv
# 06/07/2020  01:46 PM         1,754,167 deckListmodernMetaDecks2020.csv
#                7 File(s)     22,887,676 bytes
#                2 Dir(s)  439,304,028,160 bytes free

# %%
cards = pd.read_csv('data/cards.csv')

# %%
cards['cmc'] = cards['manaCost'].apply(lambda x: ''.join(''.join(str(x).split('{')).split('}')))
for index, row in cards.iterrows():
    X = row['cmc']
    list(X)
    x_ = 0
    for x in X:
        try:
            x_+=int(x)
        except:
            x_+=1
    row['cmc']=x_

# %%
cards.head()
# Out:
#                    Unnamed: 0                     colors legalities  \
# 0           "Ach! Hans, Run!"                 ['G', 'R']         {}
# 1  "Rumors of My Death . . ."                      ['B']         {}
# 2         1996 World Champion  ['B', 'G', 'R', 'U', 'W']         {}
# 3  A Display of My Dark Power                         []         {}
# 4                A Good Thing                 ['B', 'W']         {}
#
#           manaCost                        name    subtypes supertypes  \
# 0  {2}{R}{R}{G}{G}           "Ach! Hans, Run!"          []         []
# 1           {2}{B}  "Rumors of My Death . . ."          []         []
# 2  {W}{U}{B}{R}{G}         1996 World Champion  ['Legend']         []
# 3              NaN  A Display of My Dark Power          []         []
# 4        {4}{W}{B}                A Good Thing          []         []
#
#                                             text             type  \
# 0  ['creature', 'search', 'shuffle', 'creature']      Enchantment
# 1                                             []      Enchantment
# 2                           ['search', 'reveal']  Summon — Legend
# 3                     ['scheme', 'land', 'land']           Scheme
# 4                        ['sacrifice', 'double']      Enchantment
#
#              types                                  uuid power toughness  \
# 0  ['Enchantment']  8f9a35d5-a3a2-556b-88da-6686da3aaa34   NaN       NaN
# 1  ['Enchantment']  201f7042-dda1-53d6-a0bd-8225ba73f34a   NaN       NaN
# 2       ['Summon']  6b0e48c0-441d-5a62-a558-3c99473e4387   NaN       NaN
# 3       ['Scheme']  5ccf5ac6-84e6-5ae8-a801-6e9cac2f1996   NaN       NaN
# 4  ['Enchantment']  5e77de09-7521-54b6-b516-b7ed7740f7fe   NaN       NaN
#
#   leadershipSkills loyalty hasNoDeckLimit cmc
# 0              NaN     NaN            NaN   6
# 1              NaN     NaN            NaN   3
# 2              NaN     NaN            NaN   5
# 3              NaN     NaN            NaN   3
# 4              NaN     NaN            NaN   6

# %%
decks = dict()
decks['modern2018'] = pd.read_csv('data/deckListmodernMetaDecks2018.csv')
decks['modern2019'] = pd.read_csv('data/deckListmodernMetaDecks2019.csv')
decks['modern2020'] = pd.read_csv('data/deckListmodernMetaDecks2020.csv')

# %%
decklists = dict()
decklists['modern2020'] = decks['modern2020'][decks['modern2020']['1']=='Red Deck Wins']['3']
decklists['modern2019'] = decks['modern2019'][decks['modern2019']['1']=='Red Deck Wins']['3']
decklists['modern2018'] = decks['modern2018'][decks['modern2018']['1']=='Red Deck Wins']['3']

# %%
decklists['modern2020'] = decklists['modern2020'].to_dict()[0]
decklists['modern2020'] = ast.literal_eval(decklists['modern2020'])
decklists['modern2019'] = decklists['modern2019'].to_dict()[0]
decklists['modern2019'] = ast.literal_eval(decklists['modern2019'])
decklists['modern2018'] = decklists['modern2018'].to_dict()[1]
decklists['modern2018'] = ast.literal_eval(decklists['modern2018'])

# %%
sim = dict()
for i,deck in enumerate(decklists['modern2020']):
    for ty in deck:
        for card in deck[ty]:
            card = card.split(' ')
            freq = card[0]
            name = ' '.join(card[1:])
            if name not in sim:
                sim[name] = list()
                sim[name].append([i,int(freq)])
            else:
                isIn = False
                for i_,freq_ in sim[name]:
                    if i_==i:
                        isIn=True
                        freq_+=int(freq)
                if isIn==False:
                    sim[name].append([i,int(freq)])
